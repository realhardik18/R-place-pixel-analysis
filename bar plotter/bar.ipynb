# %%
from matplotlib.pyplot import bar
import pandas

# %%
df = pandas.read_csv(r'C:\Users\hardik\OneDrive\Documents\GitHub\R-place-pixel-analysis\bar plotter\data.csv')
sorted_df = df.sort_values('percentage', ascending=False)
sorted_df
# Out:
#       color  percentage
# 3   #000000   23.415375
# 1   #ffffff   13.103525
# 4   #ff4500    6.896275
# 10  #2450a4    5.938500
# 8   #ffd635    5.717200
# 2   #ffa800    4.204200
# 9   #be0039    4.186200
# 5   #3690ea    3.507125
# 17  #d4d7d9    3.466300
# 16  #898d90    3.151325
# 26  #51e9f4    3.101475
# 21  #00a368    2.759425
# 20  #9c6926    2.348775
# 11  #6d482f    1.722350
# 6   #811e9f    1.674950
# 18  #7eed56    1.640150
# 12  #ff99aa    1.637575
# 15  #515252    1.552775
# 19  #ffb470    1.498850
# 27  #fff8b8    1.170050
# 22  #00cc78    1.095350
# 28  #6d001a    1.022150
# 13  #00756f    0.909050
# 23  #ff3881    0.837775
# 7   #b44ac0    0.802250
# 24  #94b3ff    0.605300
# 14  #493ac1    0.545025
# 30  #6a5cff    0.415900
# 25  #009eaa    0.355750
# 0   #de107f    0.278550
# 31  #e4abff    0.272400
# 29  #00ccc0    0.168100

# %%
bargraph = sorted_df.plot.bar(x='color', y='percentage', fontsize='9',width=1, edgecolor='white', linewidth=3)

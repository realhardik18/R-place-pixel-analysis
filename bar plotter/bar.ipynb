# %%
from matplotlib.pyplot import bar
import pandas

# %%
df = pandas.read_csv(r'C:\Users\hardik\OneDrive\Documents\GitHub\R-place-pixel-analysis\bar plotter\data.csv')
sorted_df = df.sort_values('percentage', ascending=False)
sorted_df.head()
# Out:
#       color  percentage
# 3   #000000   23.415375
# 1   #ffffff   13.103525
# 4   #ff4500    6.896275
# 10  #2450a4    5.938500
# 8   #ffd635    5.717200

# %%
bargraph = df.plot.bar(x='color', y='percentage', fontsize='18',width=1, edgecolor='white', linewidth=3)
